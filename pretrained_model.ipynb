# %%
import torch
import os
import torchvision
from input_pipeline import ImageLoader
from data_manager.manage_csv import *
import pandas as pd
from evaluation_metrics import eval_scores, print_eval_scores
from input_pipeline import create_dataset_split
import numpy as np

# %%
""" Define batch size, number of epochs for training and dataset paths """

PATH_TO_IMAGES = 'data/img_align_celeba'
PATH_TO_LABELS = 'data/list_attr_celeba.csv'
PATH_TO_MODELS = 'models/'
PATH_TO_VALIDATION_SCORES = 'metadata/validation_scores.csv'
BATCH_SIZE = 128
NUM_EPOCHS = 2

# %%
""" Load pretrained model and dataset """ 

model = torch.hub.load('pytorch/vision:v0.10.0', 'mobilenet_v2', weights=torchvision.models.MobileNet_V2_Weights.IMAGENET1K_V2)
dataset = ImageLoader(PATH_TO_IMAGES, PATH_TO_LABELS, augment=False)
train_data, val_data, test_data = create_dataset_split(dataset=dataset, batch_size=BATCH_SIZE)
# Out:
# Using cache found in /Users/peterbrezovcsik/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
""" Create classifier for the core model """

classifier_1 = torch.nn.Sequential(
    torch.nn.Dropout(0.3),
    torch.nn.Linear(1280, 128),
    torch.nn.BatchNorm1d(128),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(128, 64),
    torch.nn.BatchNorm1d(64),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.1),
    torch.nn.Linear(64, 40)
)

# %%
classifier_2 = torch.nn.Sequential(
    torch.nn.Dropout(0.3),
    torch.nn.Linear(1280, 128),
    torch.nn.BatchNorm1d(128),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(128, 40)
)

# %%
classifier_3 = torch.nn.Sequential(
    torch.nn.Dropout(0.3),
    torch.nn.Linear(1280, 40)
)
model.classifier = classifier_3

# %%
""" Reset weight parameters of the classifier """

for layer in model.classifier.children():
    if hasattr(layer, 'reset_parameters'):
        layer.reset_parameters()

# %%
""" Define loss function and optimizer """

loss = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
""" Define model metadata to store in model_metadata.csv """

VERSION_NUM = 4

MODEL_ID = 'MOBILE_NET_V2' + '_' + str(VERSION_NUM)
NUM_OF_HEAD_LAYERS = len(model.classifier) 
LOSS_NAME = loss.__class__.__name__
OPTI_NAME = optimizer.__class__.__name__
LEARNING_RATE = optimizer.defaults['lr']
CLASSIFICATION_THRESHOLD = 0.6



""" Define model metadata file path and header """

MODEL_METADATA_PATH = 'metadata/'
MODEL_METADATA_FILE = 'model_metadata.csv'
MODEL_METADATA_HEADER = ['model_id', 'num_of_head_layers', 'batch_size', 'num_epochs', 'loss_fn', 'optimizer', 'learning_rate', 'threshold']
MODEL_ARGS = [MODEL_ID, NUM_OF_HEAD_LAYERS, BATCH_SIZE, NUM_EPOCHS, LOSS_NAME, OPTI_NAME, LEARNING_RATE, CLASSIFICATION_THRESHOLD]


""" Define class_wise_accuracy file path and header """

CLASS_WISE_ACCURACY_FILE = 'class_wise_accuracy.csv'
CLASS_WISE_ACCURACY_HEADER = dataset.attr_names


""" Define validation scores file path and header """

VALIDATION_SCORES_FILE = 'validation_scores.csv' 
VALIDATION_SCORES_HEADER = ['model_id', 'epoch', 'f1_score', 'recall_score', 'precision_score', 'hamming_loss', 'hamming_score', 'partial_accuracy', 'loss']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 VERSION_NUM = 3
#       5 MODEL_ID = 'MOBILE_NET_V2' + '_' + str(VERSION_NUM)
# ----> 6 NUM_OF_HEAD_LAYERS = len(model.classifier)
#       7 LOSS_NAME = loss.__class__.__name__
#       8 OPTI_NAME = optimizer.__class__.__name__
#
# NameError: name 'model' is not defined

# %%
def save_model(model_id, current_accuracy):
    df = pd.read_csv(PATH_TO_VALIDATION_SCORES)
    best_accuracy = df.loc[df['model_id'] == model_id]['partial_accuracy'].max()
    if current_accuracy > best_accuracy or best_accuracy is np.nan:
        print('Saving model...')
        model_path = model_id + '.pth'
        path = os.path.join(PATH_TO_MODELS, model_path)
        torch.save(model.state_dict(), path)

# %%
metric_saver = MetricSaver(MODEL_METADATA_PATH)

metric_saver.create_model_metadata_csv(MODEL_METADATA_FILE, MODEL_METADATA_HEADER)
metric_saver.create_class_wise_acc_csv(CLASS_WISE_ACCURACY_FILE, *CLASS_WISE_ACCURACY_HEADER)
metric_saver.create_validation_scores_csv(VALIDATION_SCORES_FILE, VALIDATION_SCORES_HEADER)

metric_saver.save_model_metadata(*MODEL_ARGS)
# Out:
# model_metadata.csv.csv already exists.
# class_wise_accuracy.csv already exists.
# validation_scores.csv already exists.
# Saving model metadata...

# %%
""" Validation function for the classifier """

def validate(model, val_data, epoch, model_id, loss_fn):
    model.eval()
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    
    avg_partial_accuracy = avg_f1_score = avg_recall_score = avg_precision_score = avg_hamming_loss = avg_hamming_score = avg_loss = 0.0
    avg_label_wise_accuracy_score = np.zeros(shape=(40))

    NUM_OF_BATCHES = len(val_data)
    
    for i, batch in enumerate(val_data):
        with torch.no_grad():
            images, labels = batch
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)

            loss = loss_fn(outputs, labels)

            result = outputs > CLASSIFICATION_THRESHOLD

            f1_score, recall, precision, hamming_loss, ham_score, partial_accuracy, label_wise_accuracy =\
                        eval_scores(labels.cpu().detach().numpy(), result.cpu().detach().numpy(), loss.item(), print_out=True, epoch=epoch, batch=i)
            
            ### Increase average scores by the current batch scores
            avg_f1_score += f1_score
            avg_recall_score += recall
            avg_precision_score += precision
            avg_hamming_loss += hamming_loss
            avg_hamming_score += ham_score
            avg_partial_accuracy += partial_accuracy
            avg_label_wise_accuracy_score += label_wise_accuracy
            avg_loss += loss.item()
            
    ### Calculate average scores
    avg_f1_score /= NUM_OF_BATCHES
    avg_recall_score /= NUM_OF_BATCHES
    avg_precision_score /= NUM_OF_BATCHES
    avg_hamming_loss /= NUM_OF_BATCHES
    avg_hamming_score /= NUM_OF_BATCHES
    avg_partial_accuracy /= NUM_OF_BATCHES
    avg_label_wise_accuracy_score /= NUM_OF_BATCHES
    avg_loss /= NUM_OF_BATCHES
    
    

    ### Save validation scores to csv file
    save_model(model_id, avg_partial_accuracy)
    metric_saver.save_class_wise_accuracy(model_id, epoch+1, *avg_label_wise_accuracy_score)
    metric_saver.save_validation_scores(model_id, epoch+1, *(avg_f1_score, avg_recall_score, avg_precision_score, avg_hamming_loss, avg_hamming_score, avg_partial_accuracy, avg_loss))

    print_eval_scores(avg_f1_score, avg_recall_score, avg_precision_score, avg_hamming_loss, avg_hamming_score, avg_partial_accuracy, avg_label_wise_accuracy_score, avg_loss)

# %%
""" Training function for the classifier """

def fit(model, train_data, val_data, optimizer, loss_fn, epochs, model_id):
        
        # Froze feature layers
        for param in model.features.parameters():
            param.requires_grad = False

        device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

        for epoch in range(epochs):
            model.train(mode=True)
            
            for i, batch in enumerate(train_data):
                images, labels = batch
                images = images.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                loss.backward()
                optimizer.step()
                
                result = outputs > CLASSIFICATION_THRESHOLD
                # Measure model performance for every batch
                f1_score, recall, precision, hamming_loss, ham_score, partial_accuracy, label_wise_accuracy =\
                      eval_scores(labels.cpu().detach().numpy(), result.cpu().detach().numpy(), loss.item(), print_out=True, epoch=epoch, batch=i)
            
            # Evaluetion metrics for every epoch
                
            validate(model, val_data, epoch, model_id, loss_fn)

# %%
""" Train the model """

fit(model, train_data, val_data, optimizer, loss, NUM_EPOCHS, MODEL_ID)
# Out:
# ======================== Epoch: 1, Batch: 1 ========================
# F1 score:
# 0.008987713675213676
# Recall:
# 0.005072206439393939
# Precision:
# 0.045572916666666664
# Hamming loss:
# 0.2193359375
# Hamming score:
# 0.00490817775974026
# Partial accuracy:
# 0.7806640625
# Label wise accuracy:
# [0.890625  0.7734375 0.515625  0.8125    0.953125  0.890625  0.7890625
#  0.8046875 0.7578125 0.84375   0.9375    0.7578125 0.8828125 0.9375
#  0.9375    0.921875  0.921875  0.96875   0.7109375 0.59375   0.53125
#  0.578125  0.9453125 0.9140625 0.1484375 0.6796875 0.9296875 0.7109375
#  0.9140625 0.9375    0.9375    0.546875  0.796875  0.65625   0.84375
#  0.9375    0.6015625 0.8984375 0.8984375 0.21875  ]
# Loss:
# 0.6944727301597595
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 2 ========================
# F1 score:
# 0.017355647824397823
# Recall:
# 0.00962374533146592
# Precision:
# 0.09375
# Hamming loss:
# 0.21640625
# Hamming score:
# 0.00962374533146592
# Partial accuracy:
# 0.78359375
# Label wise accuracy:
# [0.890625  0.7109375 0.5234375 0.75      0.9765625 0.8984375 0.7578125
#  0.828125  0.71875   0.875     0.9375    0.8125    0.890625  0.96875
#  0.9609375 0.921875  0.90625   0.96875   0.6015625 0.6171875 0.5546875
#  0.5390625 0.9609375 0.875     0.2734375 0.765625  0.953125  0.71875
#  0.921875  0.9140625 0.9453125 0.5546875 0.828125  0.65625   0.828125
#  0.953125  0.5546875 0.8984375 0.921875  0.2109375]
# Loss:
# 0.6329740285873413
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 3 ========================
# F1 score:
# 0.11714151733682984
# Recall:
# 0.06786631337412588
# Precision:
# 0.515625
# Hamming loss:
# 0.2240234375
# Hamming score:
# 0.0677365819943945
# Partial accuracy:
# 0.7759765625
# Label wise accuracy:
# [0.9140625 0.6953125 0.5       0.8125    0.9765625 0.796875  0.6953125
#  0.7109375 0.765625  0.8359375 0.9296875 0.765625  0.8125    0.953125
#  0.953125  0.9296875 0.9296875 0.984375  0.6015625 0.5859375 0.609375
#  0.4609375 0.9765625 0.875     0.5390625 0.75      0.96875   0.7890625
#  0.9296875 0.921875  0.9453125 0.53125   0.8125    0.5625    0.8046875
#  0.96875   0.4921875 0.8125    0.9375    0.203125 ]
# Loss:
# 0.5818144679069519
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 4 ========================
# F1 score:
# 0.23035592369232077
# Recall:
# 0.1410830055361305
# Precision:
# 0.7578125
# Hamming loss:
# 0.200390625
# Hamming score:
# 0.13940785776723277
# Partial accuracy:
# 0.799609375
# Label wise accuracy:
# [0.8984375 0.7578125 0.4765625 0.8203125 0.984375  0.8359375 0.765625
#  0.7734375 0.71875   0.890625  0.953125  0.8125    0.8515625 0.9296875
#  0.9140625 0.9375    0.9375    0.9296875 0.6171875 0.578125  0.640625
#  0.53125   0.9609375 0.8984375 0.71875   0.734375  0.953125  0.7265625
#  0.9375    0.96875   0.953125  0.5546875 0.65625   0.734375  0.78125
#  0.9765625 0.484375  0.8828125 0.921875  0.5859375]
# Loss:
# 0.541803777217865
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 5 ========================
# F1 score:
# 0.2926173193636429
# Recall:
# 0.1842269059065934
# Precision:
# 0.859375
# Hamming loss:
# 0.20546875
# Hamming score:
# 0.18215000060703185
# Partial accuracy:
# 0.79453125
# Label wise accuracy:
# [0.8984375 0.625     0.515625  0.796875  0.9921875 0.8046875 0.75
#  0.796875  0.703125  0.828125  0.9453125 0.78125   0.890625  0.9609375
#  0.953125  0.9765625 0.9921875 0.9609375 0.5390625 0.4765625 0.6484375
#  0.4609375 1.        0.8515625 0.8984375 0.6796875 0.984375  0.7109375
#  0.9453125 0.921875  0.9609375 0.421875  0.765625  0.640625  0.75
#  0.984375  0.4921875 0.90625   0.8984375 0.671875 ]
# Loss:
# 0.511806309223175
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 6 ========================
# F1 score:
# 0.32791362726540746
# Recall:
# 0.21096560327948197
# Precision:
# 0.8255208333333333
# Hamming loss:
# 0.1845703125
# Hamming score:
# 0.2061343451279113
# Partial accuracy:
# 0.8154296875
# Label wise accuracy:
# [0.8359375 0.78125   0.4609375 0.7890625 0.984375  0.9140625 0.78125
#  0.765625  0.734375  0.859375  0.9375    0.7578125 0.8359375 0.9765625
#  0.984375  0.953125  0.953125  0.9375    0.640625  0.5546875 0.5390625
#  0.6484375 0.9921875 0.890625  0.828125  0.703125  0.9765625 0.7109375
#  0.9375    0.9375    0.921875  0.625     0.78125   0.703125  0.8359375
#  0.953125  0.5625    0.8828125 0.9375    0.8125   ]
# Loss:
# 0.4823697507381439
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 7 ========================
# F1 score:
# 0.30322840456112515
# Recall:
# 0.19360332592754467
# Precision:
# 0.7916666666666666
# Hamming loss:
# 0.19765625
# Hamming score:
# 0.18900844483335294
# Partial accuracy:
# 0.80234375
# Label wise accuracy:
# [0.90625   0.6953125 0.46875   0.828125  0.984375  0.84375   0.78125
#  0.796875  0.7578125 0.828125  0.96875   0.8046875 0.8046875 0.9375
#  0.9375    0.9609375 0.8984375 0.9609375 0.5859375 0.5       0.546875
#  0.53125   0.9609375 0.9140625 0.765625  0.7109375 0.9609375 0.71875
#  0.953125  0.921875  0.9296875 0.5078125 0.8203125 0.65625   0.8359375
#  0.9453125 0.53125   0.90625   0.90625   0.8203125]
# Loss:
# 0.4697642922401428
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 8 ========================
# F1 score:
# 0.3168575571100726
# Recall:
# 0.2016152314291101
# Precision:
# 0.84375
# Hamming loss:
# 0.196875
# Hamming score:
# 0.19725277530884147
# Partial accuracy:
# 0.803125
# Label wise accuracy:
# [0.9453125 0.7265625 0.4609375 0.7734375 0.984375  0.7890625 0.7890625
#  0.8046875 0.7265625 0.8203125 0.9296875 0.828125  0.8359375 0.9375
#  0.96875   0.953125  0.9765625 0.9921875 0.5625    0.5       0.6171875
#  0.5859375 0.9609375 0.859375  0.890625  0.6328125 0.9453125 0.7109375
#  0.9375    0.9296875 0.953125  0.4921875 0.7578125 0.6640625 0.84375
#  0.953125  0.5078125 0.890625  0.8984375 0.7890625]
# Loss:
# 0.4549506604671478
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 9 ========================
# F1 score:
# 0.31235076641302456
# Recall:
# 0.2024783440109727
# Precision:
# 0.7981770833333334
# Hamming loss:
# 0.1990234375
# Hamming score:
# 0.19731425896407515
# Partial accuracy:
# 0.8009765625
# Label wise accuracy:
# [0.890625  0.796875  0.5       0.828125  0.9609375 0.8125    0.7578125
#  0.7890625 0.71875   0.8671875 0.9765625 0.8125    0.8828125 0.9609375
#  0.9765625 0.984375  0.96875   0.9375    0.5625    0.5       0.625
#  0.5078125 0.9609375 0.828125  0.828125  0.65625   0.9765625 0.703125
#  0.953125  0.8984375 0.9453125 0.421875  0.78125   0.7109375 0.7109375
#  0.96875   0.484375  0.90625   0.9140625 0.7734375]
# Loss:
# 0.44296446442604065
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 10 ========================
# F1 score:
# 0.3174532641716514
# Recall:
# 0.2053947775570018
# Precision:
# 0.7877604166666667
# Hamming loss:
# 0.198046875
# Hamming score:
# 0.19854940619531614
# Partial accuracy:
# 0.801953125
# Label wise accuracy:
# [0.890625  0.7578125 0.4609375 0.8203125 0.9765625 0.796875  0.7734375
#  0.75      0.78125   0.8828125 0.9375    0.8359375 0.8203125 0.9453125
#  0.9921875 0.8984375 0.921875  0.96875   0.578125  0.546875  0.5703125
#  0.578125  0.9453125 0.921875  0.8125    0.7265625 0.953125  0.6640625
#  0.9296875 0.90625   0.921875  0.5078125 0.765625  0.6875    0.8046875
#  0.9296875 0.5234375 0.890625  0.9140625 0.7890625]
# Loss:
# 0.44057074189186096
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 11 ========================
# F1 score:
# 0.3205210345720456
# Recall:
# 0.20704048555611057
# Precision:
# 0.7916666666666666
# Hamming loss:
# 0.1943359375
# Hamming score:
# 0.20264063193750695
# Partial accuracy:
# 0.8056640625
# Label wise accuracy:
# [0.859375  0.7421875 0.5546875 0.7890625 0.96875   0.8046875 0.734375
#  0.7421875 0.6953125 0.8125    0.953125  0.8828125 0.8671875 0.953125
#  0.96875   0.953125  0.9140625 0.984375  0.5625    0.625     0.578125
#  0.5625    0.9375    0.8671875 0.8125    0.75      0.953125  0.734375
#  0.921875  0.96875   0.921875  0.578125  0.796875  0.65625   0.796875
#  0.9609375 0.5       0.890625  0.90625   0.765625 ]
# Loss:
# 0.44005656242370605
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 12 ========================
# F1 score:
# 0.3277331928182112
# Recall:
# 0.21208624275030527
# Precision:
# 0.79296875
# Hamming loss:
# 0.18828125
# Hamming score:
# 0.2062514200209513
# Partial accuracy:
# 0.81171875
# Label wise accuracy:
# [0.8515625 0.765625  0.6171875 0.7734375 0.9765625 0.8671875 0.8359375
#  0.71875   0.6875    0.8125    0.96875   0.8203125 0.8046875 0.953125
#  0.984375  0.9296875 0.921875  0.9375    0.5859375 0.5859375 0.5390625
#  0.5625    0.9453125 0.8828125 0.8125    0.65625   0.9921875 0.7734375
#  0.875     0.9375    0.921875  0.59375   0.796875  0.71875   0.890625
#  0.953125  0.640625  0.8984375 0.8984375 0.78125  ]
# Loss:
# 0.43323197960853577
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 13 ========================
# F1 score:
# 0.334374330680929
# Recall:
# 0.2164905980967562
# Precision:
# 0.8151041666666666
# Hamming loss:
# 0.196484375
# Hamming score:
# 0.20846437187200056
# Partial accuracy:
# 0.803515625
# Label wise accuracy:
# [0.8984375 0.65625   0.5390625 0.875     1.        0.859375  0.7265625
#  0.8046875 0.765625  0.7890625 0.9375    0.7734375 0.859375  0.9375
#  0.9609375 0.9453125 0.9296875 0.953125  0.5625    0.5546875 0.6171875
#  0.5234375 0.96875   0.8828125 0.8671875 0.7421875 0.9453125 0.65625
#  0.9375    0.9296875 0.9453125 0.4921875 0.8203125 0.6328125 0.7578125
#  0.984375  0.5625    0.84375   0.921875  0.78125  ]
# Loss:
# 0.4286127984523773
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 14 ========================
# F1 score:
# 0.3287581077145464
# Recall:
# 0.21163748361013987
# Precision:
# 0.8001302083333334
# Hamming loss:
# 0.19453125
# Hamming score:
# 0.2080051133762071
# Partial accuracy:
# 0.80546875
# Label wise accuracy:
# [0.9296875 0.7421875 0.6015625 0.75      0.984375  0.875     0.734375
#  0.7109375 0.6875    0.859375  0.9375    0.84375   0.875     0.9296875
#  0.953125  0.9375    0.9453125 0.921875  0.6640625 0.515625  0.59375
#  0.53125   0.9453125 0.8828125 0.875     0.7109375 0.9453125 0.7890625
#  0.8984375 0.890625  0.953125  0.5234375 0.734375  0.6875    0.8203125
#  0.9296875 0.5546875 0.8828125 0.9453125 0.7265625]
# Loss:
# 0.43079257011413574
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 15 ========================
# F1 score:
# 0.3451087579189601
# Recall:
# 0.22401630487567986
# Precision:
# 0.81640625
# Hamming loss:
# 0.18984375
# Hamming score:
# 0.21828902434371183
# Partial accuracy:
# 0.81015625
# Label wise accuracy:
# [0.875     0.71875   0.5234375 0.7578125 0.984375  0.9140625 0.8359375
#  0.75      0.8359375 0.828125  0.9453125 0.78125   0.8359375 0.9453125
#  0.9453125 0.96875   0.9453125 0.9296875 0.625     0.53125   0.6328125
#  0.53125   0.9765625 0.890625  0.8515625 0.6953125 0.9765625 0.7109375
#  0.9140625 0.8984375 0.9296875 0.546875  0.796875  0.640625  0.7734375
#  0.96875   0.6171875 0.890625  0.8984375 0.7890625]
# Loss:
# 0.423900306224823
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 16 ========================
# F1 score:
# 0.33950895152641475
# Recall:
# 0.22202712651931403
# Precision:
# 0.7993489583333333
# Hamming loss:
# 0.18984375
# Hamming score:
# 0.21395349442224443
# Partial accuracy:
# 0.81015625
# Label wise accuracy:
# [0.8984375 0.7578125 0.625     0.7890625 1.        0.828125  0.796875
#  0.78125   0.6640625 0.84375   0.9296875 0.7734375 0.8515625 0.9296875
#  0.96875   0.9609375 0.9296875 0.984375  0.6171875 0.546875  0.609375
#  0.5078125 0.9765625 0.8984375 0.8515625 0.640625  0.9609375 0.78125
#  0.8984375 0.8828125 0.953125  0.5       0.75      0.75      0.8046875
#  0.984375  0.6171875 0.8359375 0.9609375 0.765625 ]
# Loss:
# 0.4233967363834381
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 17 ========================
# F1 score:
# 0.37698648772323307
# Recall:
# 0.254004448880368
# Precision:
# 0.83203125
# Hamming loss:
# 0.1802734375
# Hamming score:
# 0.24797935737159083
# Partial accuracy:
# 0.8197265625
# Label wise accuracy:
# [0.875     0.7109375 0.640625  0.8125    0.984375  0.84375   0.7265625
#  0.75      0.7578125 0.8984375 0.9609375 0.7109375 0.859375  0.921875
#  0.9609375 0.921875  0.9765625 0.9765625 0.609375  0.625     0.6328125
#  0.5703125 0.984375  0.8671875 0.890625  0.7421875 0.9609375 0.6953125
#  0.9140625 0.9375    0.9609375 0.640625  0.8359375 0.6328125 0.828125
#  0.9453125 0.578125  0.9140625 0.9375    0.796875 ]
# Loss:
# 0.41122597455978394
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 18 ========================
# F1 score:
# 0.33861707614549624
# Recall:
# 0.22224841641201934
# Precision:
# 0.7838541666666666
# Hamming loss:
# 0.1943359375
# Hamming score:
# 0.21566077662125457
# Partial accuracy:
# 0.8056640625
# Label wise accuracy:
# [0.859375  0.7265625 0.65625   0.8046875 0.9765625 0.828125  0.703125
#  0.765625  0.7265625 0.8515625 0.9453125 0.8359375 0.8125    0.90625
#  0.9296875 0.921875  0.9609375 0.96875   0.609375  0.609375  0.5859375
#  0.4921875 0.96875   0.859375  0.8125    0.703125  0.921875  0.734375
#  0.9453125 0.9453125 0.9375    0.5703125 0.7578125 0.703125  0.7578125
#  0.9453125 0.6015625 0.90625   0.9140625 0.765625 ]
# Loss:
# 0.4303218424320221
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 19 ========================
# F1 score:
# 0.31850917346757124
# Recall:
# 0.2067205580877456
# Precision:
# 0.76640625
# Hamming loss:
# 0.194921875
# Hamming score:
# 0.19928437001621746
# Partial accuracy:
# 0.805078125
# Label wise accuracy:
# [0.875     0.796875  0.515625  0.71875   1.        0.8671875 0.78125
#  0.734375  0.796875  0.8046875 0.9453125 0.7890625 0.84375   0.9609375
#  0.9453125 0.96875   0.9375    0.9921875 0.65625   0.53125   0.5234375
#  0.453125  0.953125  0.828125  0.7890625 0.7578125 0.96875   0.7109375
#  0.8984375 0.9296875 0.9296875 0.5078125 0.828125  0.6796875 0.859375
#  0.9375    0.640625  0.8671875 0.9375    0.7421875]
# Loss:
# 0.41993752121925354
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 20 ========================
# F1 score:
# 0.3913850386530824
# Recall:
# 0.26755061344905096
# Precision:
# 0.8372395833333334
# Hamming loss:
# 0.17265625
# Hamming score:
# 0.2600184320887446
# Partial accuracy:
# 0.82734375
# Label wise accuracy:
# [0.90625   0.6953125 0.625     0.8046875 0.9765625 0.875     0.7890625
#  0.8046875 0.7734375 0.921875  0.953125  0.7578125 0.8984375 0.96875
#  0.96875   0.9296875 0.9375    0.9609375 0.609375  0.578125  0.6328125
#  0.5625    0.96875   0.90625   0.84375   0.7265625 0.953125  0.6953125
#  0.9453125 0.9296875 0.9375    0.6328125 0.8515625 0.6953125 0.84375
#  0.96875   0.6953125 0.8359375 0.921875  0.8125   ]
# Loss:
# 0.3942754864692688
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 21 ========================
# F1 score:
# 0.3505552313509569
# Recall:
# 0.23011761459027083
# Precision:
# 0.8053385416666666
# Hamming loss:
# 0.18046875
# Hamming score:
# 0.22251816109237982
# Partial accuracy:
# 0.81953125
# Label wise accuracy:
# [0.9140625 0.7578125 0.5546875 0.84375   0.984375  0.8671875 0.75
#  0.7734375 0.8125    0.84375   0.921875  0.796875  0.90625   0.96875
#  0.9609375 0.9296875 0.9375    0.9609375 0.5703125 0.59375   0.640625
#  0.5       0.953125  0.90625   0.828125  0.796875  0.96875   0.6640625
#  0.9375    0.9296875 0.96875   0.5703125 0.8125    0.625     0.8515625
#  0.9609375 0.59375   0.8828125 0.9453125 0.796875 ]
# Loss:
# 0.3899577260017395
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 22 ========================
# F1 score:
# 0.39702811700683216
# Recall:
# 0.2696662712287712
# Precision:
# 0.8184895833333333
# Hamming loss:
# 0.16171875
# Hamming score:
# 0.2613442113442113
# Partial accuracy:
# 0.83828125
# Label wise accuracy:
# [0.921875  0.8046875 0.59375   0.7890625 0.9921875 0.8984375 0.7734375
#  0.8359375 0.7734375 0.875     0.953125  0.796875  0.8515625 0.9375
#  0.9375    0.90625   0.9375    0.9453125 0.671875  0.71875   0.6171875
#  0.6875    0.9765625 0.890625  0.828125  0.6484375 0.953125  0.75
#  0.8828125 0.9921875 0.9375    0.71875   0.796875  0.765625  0.84375
#  0.9453125 0.71875   0.90625   0.953125  0.8046875]
# Loss:
# 0.39488598704338074
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 23 ========================
# F1 score:
# 0.35974017335702224
# Recall:
# 0.2380888859404484
# Precision:
# 0.8135416666666666
# Hamming loss:
# 0.1853515625
# Hamming score:
# 0.23062279517357642
# Partial accuracy:
# 0.8146484375
# Label wise accuracy:
# [0.8515625 0.7578125 0.65625   0.8046875 0.984375  0.7734375 0.796875
#  0.7109375 0.796875  0.859375  0.9296875 0.8046875 0.84375   0.9609375
#  0.953125  0.953125  0.953125  0.9609375 0.640625  0.5859375 0.5859375
#  0.5625    0.953125  0.8359375 0.8515625 0.6484375 0.9296875 0.765625
#  0.9375    0.921875  0.9609375 0.5390625 0.8515625 0.625     0.8125
#  0.96875   0.6640625 0.875     0.953125  0.765625 ]
# Loss:
# 0.407052218914032
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 24 ========================
# F1 score:
# 0.3548055672934737
# Recall:
# 0.23407699071761573
# Precision:
# 0.8203125
# Hamming loss:
# 0.1845703125
# Hamming score:
# 0.22580931438353316
# Partial accuracy:
# 0.8154296875
# Label wise accuracy:
# [0.875     0.703125  0.671875  0.8125    0.984375  0.84375   0.7578125
#  0.828125  0.7734375 0.8203125 0.96875   0.8203125 0.890625  0.96875
#  0.96875   0.953125  0.9765625 0.9609375 0.6328125 0.515625  0.640625
#  0.53125   0.9921875 0.8828125 0.8671875 0.6484375 0.9375    0.6875
#  0.921875  0.9453125 0.9765625 0.453125  0.71875   0.6953125 0.828125
#  0.9609375 0.59375   0.890625  0.9453125 0.7734375]
# Loss:
# 0.3915945589542389
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 25 ========================
# F1 score:
# 0.35142663574600497
# Recall:
# 0.2313872975982351
# Precision:
# 0.8151041666666667
# Hamming loss:
# 0.18359375
# Hamming score:
# 0.22369399263930512
# Partial accuracy:
# 0.81640625
# Label wise accuracy:
# [0.9453125 0.7265625 0.625     0.859375  0.96875   0.890625  0.7265625
#  0.765625  0.71875   0.921875  0.9765625 0.8203125 0.8046875 0.8984375
#  0.953125  0.9375    0.9296875 0.9609375 0.625     0.609375  0.6953125
#  0.5703125 0.9296875 0.8984375 0.8359375 0.703125  0.9453125 0.7265625
#  0.9140625 0.953125  0.9453125 0.578125  0.8046875 0.65625   0.8203125
#  0.953125  0.5546875 0.8515625 0.8828125 0.7734375]
# Loss:
# 0.40874752402305603
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 26 ========================
# F1 score:
# 0.36797625675032314
# Recall:
# 0.2458994130869131
# Precision:
# 0.8194010416666666
# Hamming loss:
# 0.1828125
# Hamming score:
# 0.23840662375818625
# Partial accuracy:
# 0.8171875
# Label wise accuracy:
# [0.8984375 0.7109375 0.65625   0.84375   0.9609375 0.84375   0.78125
#  0.78125   0.7578125 0.8515625 0.953125  0.796875  0.84375   0.9765625
#  0.9609375 0.890625  0.96875   0.953125  0.5859375 0.5078125 0.6796875
#  0.5859375 0.9921875 0.8984375 0.84375   0.6796875 0.9453125 0.734375
#  0.921875  0.9140625 0.96875   0.5859375 0.8203125 0.625     0.8046875
#  0.984375  0.578125  0.8359375 0.9609375 0.8046875]
# Loss:
# 0.3984844386577606
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 27 ========================
# F1 score:
# 0.3681351144501783
# Recall:
# 0.24440117174492174
# Precision:
# 0.8243489583333334
# Hamming loss:
# 0.1865234375
# Hamming score:
# 0.23710787017312754
# Partial accuracy:
# 0.8134765625
# Label wise accuracy:
# [0.8828125 0.6875    0.625     0.7734375 0.96875   0.84375   0.7734375
#  0.71875   0.765625  0.8203125 0.953125  0.7578125 0.8984375 0.9453125
#  0.9453125 0.9609375 0.9609375 0.9453125 0.6015625 0.5390625 0.71875
#  0.5859375 0.9921875 0.8984375 0.875     0.7578125 0.96875   0.7421875
#  0.90625   0.921875  0.953125  0.5234375 0.8046875 0.65625   0.7578125
#  0.9453125 0.609375  0.84375   0.9453125 0.765625 ]
# Loss:
# 0.40446218848228455
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 28 ========================
# F1 score:
# 0.35960909192877555
# Recall:
# 0.2382966671258201
# Precision:
# 0.8125
# Hamming loss:
# 0.1884765625
# Hamming score:
# 0.23223132277348127
# Partial accuracy:
# 0.8115234375
# Label wise accuracy:
# [0.875     0.703125  0.59375   0.7890625 0.9609375 0.8125    0.78125
#  0.7109375 0.765625  0.859375  0.96875   0.8046875 0.8828125 0.921875
#  0.953125  0.9375    0.96875   0.953125  0.6484375 0.5234375 0.625
#  0.5234375 0.96875   0.8828125 0.859375  0.7421875 0.921875  0.7578125
#  0.875     0.8828125 0.96875   0.5546875 0.8203125 0.6328125 0.796875
#  0.9375    0.7109375 0.890625  0.921875  0.7734375]
# Loss:
# 0.4089832901954651
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 29 ========================
# F1 score:
# 0.3771835046645176
# Recall:
# 0.2571031724352037
# Precision:
# 0.799609375
# Hamming loss:
# 0.1837890625
# Hamming score:
# 0.24818962504509381
# Partial accuracy:
# 0.8162109375
# Label wise accuracy:
# [0.890625  0.671875  0.6484375 0.7421875 0.9375    0.8359375 0.8125
#  0.734375  0.78125   0.8828125 0.9453125 0.7890625 0.84375   0.921875
#  0.921875  0.953125  0.9140625 0.9296875 0.6640625 0.59375   0.6328125
#  0.6015625 0.9453125 0.890625  0.8203125 0.7109375 0.9453125 0.765625
#  0.8828125 0.9140625 0.9375    0.546875  0.7734375 0.6953125 0.8515625
#  0.9609375 0.765625  0.8984375 0.90625   0.7890625]
# Loss:
# 0.41877681016921997
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 30 ========================
# F1 score:
# 0.3809281403527244
# Recall:
# 0.2572598676344081
# Precision:
# 0.8216145833333333
# Hamming loss:
# 0.1751953125
# Hamming score:
# 0.24815167981528274
# Partial accuracy:
# 0.8248046875
# Label wise accuracy:
# [0.8515625 0.7265625 0.6640625 0.8359375 0.9765625 0.859375  0.7265625
#  0.8359375 0.75      0.875     0.9609375 0.7890625 0.84375   0.9453125
#  0.953125  0.9140625 0.9375    0.953125  0.640625  0.59375   0.7265625
#  0.5625    0.96875   0.890625  0.8203125 0.7578125 0.9609375 0.78125
#  0.9140625 0.9453125 0.9375    0.5703125 0.8046875 0.7109375 0.8125
#  0.9453125 0.671875  0.8671875 0.9140625 0.796875 ]
# Loss:
# 0.39548030495643616
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 31 ========================
# F1 score:
# 0.39583768075266235
# Recall:
# 0.2703631438006438
# Precision:
# 0.8382812500000001
# Hamming loss:
# 0.175
# Hamming score:
# 0.2614343555749805
# Partial accuracy:
# 0.825
# Label wise accuracy:
# [0.8828125 0.78125   0.640625  0.8515625 1.        0.84375   0.734375
#  0.796875  0.7890625 0.8203125 0.9453125 0.8046875 0.8203125 0.9296875
#  0.953125  0.9609375 0.953125  0.96875   0.671875  0.5859375 0.640625
#  0.5234375 0.9609375 0.875     0.84375   0.6953125 0.9609375 0.703125
#  0.8984375 0.921875  0.9453125 0.6015625 0.75      0.6640625 0.875
#  0.953125  0.7734375 0.9375    0.9296875 0.8125   ]
# Loss:
# 0.38753506541252136
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 32 ========================
# F1 score:
# 0.39232932442890356
# Recall:
# 0.26769109796453544
# Precision:
# 0.8279761904761904
# Hamming loss:
# 0.1779296875
# Hamming score:
# 0.257254789481352
# Partial accuracy:
# 0.8220703125
# Label wise accuracy:
# [0.875     0.7578125 0.609375  0.78125   0.984375  0.875     0.7421875
#  0.796875  0.7421875 0.84375   0.953125  0.828125  0.8671875 0.9609375
#  0.9765625 0.96875   0.96875   0.96875   0.6015625 0.5546875 0.7265625
#  0.46875   0.9765625 0.8984375 0.8359375 0.7265625 0.9453125 0.75
#  0.9375    0.9296875 0.921875  0.5078125 0.828125  0.703125  0.8359375
#  0.9296875 0.6875    0.8671875 0.9296875 0.8203125]
# Loss:
# 0.38571763038635254
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 33 ========================
# F1 score:
# 0.3848665366630489
# Recall:
# 0.26602475215756466
# Precision:
# 0.7822916666666666
# Hamming loss:
# 0.175
# Hamming score:
# 0.25626496983918856
# Partial accuracy:
# 0.825
# Label wise accuracy:
# [0.8984375 0.7890625 0.640625  0.7734375 0.96875   0.8984375 0.7890625
#  0.7421875 0.7578125 0.8515625 0.953125  0.8125    0.828125  0.9375
#  0.921875  0.9296875 0.9453125 0.953125  0.71875   0.6171875 0.609375
#  0.5625    0.953125  0.8671875 0.84375   0.7578125 0.984375  0.7734375
#  0.9140625 0.9453125 0.9453125 0.6015625 0.7734375 0.6796875 0.796875
#  0.9609375 0.7421875 0.9140625 0.9453125 0.703125 ]
# Loss:
# 0.39196673035621643
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 34 ========================
# F1 score:
# 0.41688491408402406
# Recall:
# 0.28807166141150514
# Precision:
# 0.8495349702380952
# Hamming loss:
# 0.1662109375
# Hamming score:
# 0.28037337011946384
# Partial accuracy:
# 0.8337890625
# Label wise accuracy:
# [0.8828125 0.75      0.640625  0.8046875 0.9921875 0.890625  0.7890625
#  0.7734375 0.7734375 0.875     0.9453125 0.7578125 0.8046875 0.96875
#  0.96875   0.9375    0.9453125 0.96875   0.7265625 0.6796875 0.59375
#  0.5625    0.9609375 0.84375   0.8359375 0.671875  0.953125  0.78125
#  0.9375    0.9375    0.9609375 0.6484375 0.71875   0.7109375 0.84375
#  0.9453125 0.859375  0.8984375 0.9453125 0.8671875]
# Loss:
# 0.3798723518848419
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 35 ========================
# F1 score:
# 0.4056175333470709
# Recall:
# 0.27823763246557365
# Precision:
# 0.8460193452380953
# Hamming loss:
# 0.179296875
# Hamming score:
# 0.2703221028358896
# Partial accuracy:
# 0.820703125
# Label wise accuracy:
# [0.8984375 0.734375  0.6484375 0.8515625 1.        0.8203125 0.75
#  0.8046875 0.7421875 0.875     0.9453125 0.78125   0.828125  0.953125
#  0.96875   0.9609375 0.921875  0.96875   0.6328125 0.5234375 0.765625
#  0.4609375 0.9609375 0.8828125 0.859375  0.7109375 0.9765625 0.796875
#  0.9296875 0.921875  0.9609375 0.4921875 0.7890625 0.6796875 0.8359375
#  0.890625  0.703125  0.875     0.9375    0.7890625]
# Loss:
# 0.388310045003891
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 36 ========================
# F1 score:
# 0.4064602192129766
# Recall:
# 0.2791387215215341
# Precision:
# 0.840531994047619
# Hamming loss:
# 0.1802734375
# Hamming score:
# 0.27021017177267176
# Partial accuracy:
# 0.8197265625
# Label wise accuracy:
# [0.84375   0.703125  0.6640625 0.765625  0.9921875 0.84375   0.7265625
#  0.734375  0.703125  0.8359375 0.953125  0.828125  0.8515625 0.9765625
#  0.9609375 0.9609375 0.9453125 0.9765625 0.6484375 0.640625  0.7421875
#  0.4375    0.9609375 0.8984375 0.8203125 0.703125  0.9453125 0.703125
#  0.8984375 0.9296875 0.953125  0.6171875 0.796875  0.6875    0.828125
#  0.9453125 0.7109375 0.859375  0.953125  0.84375  ]
# Loss:
# 0.3905940055847168
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 37 ========================
# F1 score:
# 0.43197139943765817
# Recall:
# 0.30426537438256185
# Precision:
# 0.8360677083333333
# Hamming loss:
# 0.16953125
# Hamming score:
# 0.2912773424492175
# Partial accuracy:
# 0.83046875
# Label wise accuracy:
# [0.9140625 0.7265625 0.6640625 0.8359375 0.96875   0.8203125 0.7265625
#  0.828125  0.78125   0.8125    0.9453125 0.84375   0.8984375 0.921875
#  0.9609375 0.9609375 0.9375    0.9453125 0.640625  0.5859375 0.6875
#  0.53125   0.96875   0.875     0.859375  0.7421875 0.9609375 0.703125
#  0.8984375 0.953125  0.9453125 0.65625   0.765625  0.7734375 0.828125
#  0.96875   0.7265625 0.8828125 0.9453125 0.828125 ]
# Loss:
# 0.37695422768592834
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 38 ========================
# F1 score:
# 0.4124901744604724
# Recall:
# 0.29263908834221336
# Precision:
# 0.8020182291666667
# Hamming loss:
# 0.1703125
# Hamming score:
# 0.2794885019494394
# Partial accuracy:
# 0.8296875
# Label wise accuracy:
# [0.875     0.734375  0.6953125 0.765625  0.984375  0.8359375 0.71875
#  0.7578125 0.7421875 0.8671875 0.9296875 0.8359375 0.8828125 0.9453125
#  0.921875  0.9296875 0.9453125 0.9453125 0.703125  0.609375  0.7421875
#  0.578125  0.9921875 0.8984375 0.8203125 0.7890625 0.9453125 0.7734375
#  0.90625   0.9375    0.96875   0.59375   0.828125  0.6640625 0.8671875
#  0.9375    0.71875   0.8828125 0.9375    0.78125  ]
# Loss:
# 0.385951966047287
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 39 ========================
# F1 score:
# 0.4750966880798295
# Recall:
# 0.34183191578641947
# Precision:
# 0.8785807291666666
# Hamming loss:
# 0.1552734375
# Hamming score:
# 0.33020536321317573
# Partial accuracy:
# 0.8447265625
# Label wise accuracy:
# [0.9140625 0.7421875 0.7421875 0.859375  0.984375  0.8671875 0.8125
#  0.828125  0.7421875 0.8203125 0.9375    0.7421875 0.875     0.9375
#  0.9296875 0.984375  0.96875   0.9765625 0.7265625 0.609375  0.7578125
#  0.5859375 0.9921875 0.8984375 0.890625  0.7109375 0.921875  0.734375
#  0.9453125 0.953125  0.9765625 0.640625  0.7890625 0.703125  0.859375
#  0.921875  0.8046875 0.8984375 0.9453125 0.859375 ]
# Loss:
# 0.3620105981826782
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 40 ========================
# F1 score:
# 0.4483997536261468
# Recall:
# 0.3242486660857524
# Precision:
# 0.8201078869047619
# Hamming loss:
# 0.1646484375
# Hamming score:
# 0.30707964803782817
# Partial accuracy:
# 0.8353515625
# Label wise accuracy:
# [0.9140625 0.7109375 0.703125  0.84375   0.9453125 0.8046875 0.796875
#  0.8359375 0.75      0.84375   0.9375    0.8203125 0.875     0.9765625
#  0.96875   0.9453125 0.9375    0.984375  0.671875  0.625     0.8046875
#  0.671875  0.96875   0.8828125 0.828125  0.78125   0.96875   0.65625
#  0.9453125 0.9375    0.921875  0.6953125 0.7734375 0.734375  0.765625
#  0.9296875 0.6796875 0.84375   0.9296875 0.8046875]
# Loss:
# 0.3854145407676697
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 41 ========================
# F1 score:
# 0.4421464813861534
# Recall:
# 0.3258281648906649
# Precision:
# 0.7815569196428571
# Hamming loss:
# 0.1642578125
# Hamming score:
# 0.3065573532370408
# Partial accuracy:
# 0.8357421875
# Label wise accuracy:
# [0.8515625 0.7890625 0.6328125 0.859375  0.984375  0.8671875 0.8125
#  0.8046875 0.8125    0.8515625 0.96875   0.78125   0.8671875 0.953125
#  0.9609375 0.90625   0.9140625 0.9765625 0.671875  0.671875  0.7109375
#  0.6015625 0.9765625 0.890625  0.8203125 0.6640625 0.9921875 0.8046875
#  0.8828125 0.9375    0.9296875 0.6796875 0.765625  0.71875   0.8046875
#  0.953125  0.765625  0.8984375 0.921875  0.7734375]
# Loss:
# 0.3759241998195648
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 42 ========================
# F1 score:
# 0.44814580321916964
# Recall:
# 0.3201382059780497
# Precision:
# 0.8314360119047619
# Hamming loss:
# 0.1720703125
# Hamming score:
# 0.3064906556117494
# Partial accuracy:
# 0.8279296875
# Label wise accuracy:
# [0.90625   0.640625  0.75      0.7734375 0.9765625 0.8515625 0.75
#  0.78125   0.796875  0.890625  0.9765625 0.78125   0.84375   0.8984375
#  0.9140625 0.9140625 0.9296875 0.9453125 0.6796875 0.6015625 0.75
#  0.6015625 0.9375    0.8671875 0.8515625 0.75      0.96875   0.703125
#  0.9296875 0.8828125 0.9453125 0.640625  0.8203125 0.6796875 0.7578125
#  0.953125  0.796875  0.90625   0.9609375 0.8125   ]
# Loss:
# 0.39125746488571167
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 43 ========================
# F1 score:
# 0.4225460412990647
# Recall:
# 0.30092549148155767
# Precision:
# 0.8010416666666667
# Hamming loss:
# 0.17265625
# Hamming score:
# 0.28486544475744846
# Partial accuracy:
# 0.82734375
# Label wise accuracy:
# [0.859375  0.7421875 0.6875    0.84375   0.96875   0.8203125 0.75
#  0.78125   0.78125   0.8125    0.9375    0.7734375 0.859375  0.9453125
#  0.953125  0.953125  0.890625  0.9609375 0.640625  0.71875   0.703125
#  0.6484375 0.9375    0.8671875 0.7734375 0.734375  0.921875  0.7109375
#  0.890625  0.921875  0.90625   0.703125  0.8359375 0.6640625 0.8359375
#  0.953125  0.7578125 0.8671875 0.953125  0.828125 ]
# Loss:
# 0.40096062421798706
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 44 ========================
# F1 score:
# 0.43671912306667676
# Recall:
# 0.32109716646711134
# Precision:
# 0.7780970982142856
# Hamming loss:
# 0.166796875
# Hamming score:
# 0.30032592382086865
# Partial accuracy:
# 0.833203125
# Label wise accuracy:
# [0.8515625 0.75      0.78125   0.796875  0.9609375 0.84375   0.734375
#  0.75      0.78125   0.8515625 0.9765625 0.7578125 0.859375  0.9140625
#  0.9296875 0.9375    0.9140625 0.9453125 0.734375  0.6484375 0.6640625
#  0.5859375 0.9609375 0.890625  0.78125   0.796875  0.9765625 0.75
#  0.9453125 0.9765625 0.90625   0.7109375 0.78125   0.7109375 0.8359375
#  0.953125  0.8203125 0.84375   0.9453125 0.7734375]
# Loss:
# 0.38441136479377747
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 45 ========================
# F1 score:
# 0.4277210044238434
# Recall:
# 0.30237157718200913
# Precision:
# 0.8164620535714285
# Hamming loss:
# 0.177734375
# Hamming score:
# 0.2898221040856611
# Partial accuracy:
# 0.822265625
# Label wise accuracy:
# [0.890625  0.7421875 0.703125  0.7265625 0.9765625 0.8671875 0.7265625
#  0.671875  0.7578125 0.875     0.96875   0.8046875 0.90625   0.9296875
#  0.9296875 0.90625   0.921875  0.9765625 0.703125  0.5625    0.734375
#  0.546875  0.9765625 0.8671875 0.8359375 0.6796875 0.953125  0.71875
#  0.953125  0.9296875 0.921875  0.6328125 0.828125  0.6484375 0.828125
#  0.921875  0.8125    0.8359375 0.90625   0.8125   ]
# Loss:
# 0.39149531722068787
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 46 ========================
# F1 score:
# 0.4124310696579476
# Recall:
# 0.2911513616591742
# Precision:
# 0.7725818452380953
# Hamming loss:
# 0.1759765625
# Hamming score:
# 0.27582818657037406
# Partial accuracy:
# 0.8240234375
# Label wise accuracy:
# [0.8671875 0.7109375 0.75      0.796875  0.96875   0.84375   0.71875
#  0.71875   0.75      0.8125    0.953125  0.8125    0.8203125 0.9375
#  0.9609375 0.96875   0.953125  0.9296875 0.703125  0.6015625 0.734375
#  0.6484375 0.953125  0.90625   0.765625  0.7421875 0.953125  0.7421875
#  0.9140625 0.9296875 0.9453125 0.5625    0.796875  0.7421875 0.8515625
#  0.9453125 0.78125   0.796875  0.9296875 0.7421875]
# Loss:
# 0.39224565029144287
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 47 ========================
# F1 score:
# 0.41148801782206873
# Recall:
# 0.2851748747831009
# Precision:
# 0.8332031249999999
# Hamming loss:
# 0.187109375
# Hamming score:
# 0.2752136803147832
# Partial accuracy:
# 0.812890625
# Label wise accuracy:
# [0.8984375 0.6328125 0.6796875 0.765625  0.9765625 0.8671875 0.7109375
#  0.75      0.75      0.75      0.984375  0.8203125 0.8984375 0.953125
#  0.953125  0.9453125 0.9609375 0.96875   0.6484375 0.6171875 0.7578125
#  0.5703125 0.9609375 0.84375   0.8671875 0.640625  0.9453125 0.7109375
#  0.9609375 0.8984375 0.984375  0.546875  0.8203125 0.59375   0.703125
#  0.9453125 0.6875    0.828125  0.921875  0.796875 ]
# Loss:
# 0.39282146096229553
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 48 ========================
# F1 score:
# 0.45364798446826016
# Recall:
# 0.3245317182817183
# Precision:
# 0.8395833333333333
# Hamming loss:
# 0.1634765625
# Hamming score:
# 0.3125863936410811
# Partial accuracy:
# 0.8365234375
# Label wise accuracy:
# [0.921875  0.734375  0.7265625 0.796875  0.9765625 0.8515625 0.6875
#  0.7578125 0.7890625 0.859375  0.953125  0.78125   0.8671875 0.9453125
#  0.9375    0.9609375 0.953125  0.953125  0.75      0.6171875 0.7890625
#  0.640625  0.9609375 0.859375  0.84375   0.65625   0.9765625 0.78125
#  0.921875  0.890625  0.9765625 0.5859375 0.8359375 0.78125   0.8359375
#  0.9765625 0.765625  0.8515625 0.921875  0.7890625]
# Loss:
# 0.3671647608280182
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 49 ========================
# F1 score:
# 0.45972304183137574
# Recall:
# 0.3296899472565833
# Precision:
# 0.8410404265873015
# Hamming loss:
# 0.1625
# Hamming score:
# 0.3135603086660072
# Partial accuracy:
# 0.8375
# Label wise accuracy:
# [0.90625   0.71875   0.7109375 0.84375   0.953125  0.8515625 0.7578125
#  0.7578125 0.75      0.828125  0.953125  0.8515625 0.84375   0.9453125
#  0.953125  0.9453125 0.9375    0.96875   0.7265625 0.65625   0.75
#  0.5625    0.9453125 0.90625   0.828125  0.734375  0.9765625 0.71875
#  0.9609375 0.96875   0.9375    0.6171875 0.765625  0.7265625 0.8515625
#  0.9609375 0.7890625 0.875     0.9296875 0.8359375]
# Loss:
# 0.36869868636131287
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 50 ========================
# F1 score:
# 0.4361266440142824
# Recall:
# 0.3180397746401883
# Precision:
# 0.7943917410714285
# Hamming loss:
# 0.16875
# Hamming score:
# 0.30064096251481365
# Partial accuracy:
# 0.83125
# Label wise accuracy:
# [0.921875  0.6953125 0.765625  0.8125    0.953125  0.875     0.7890625
#  0.7734375 0.7890625 0.8046875 0.921875  0.828125  0.828125  0.90625
#  0.9375    0.9375    0.921875  0.953125  0.7421875 0.6953125 0.7578125
#  0.5859375 0.96875   0.8828125 0.796875  0.75      0.9609375 0.65625
#  0.9375    0.953125  0.921875  0.6015625 0.8046875 0.71875   0.828125
#  0.921875  0.7421875 0.8671875 0.9609375 0.78125  ]
# Loss:
# 0.3847227096557617
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 51 ========================
# F1 score:
# 0.44598077438860817
# Recall:
# 0.3223771454240204
# Precision:
# 0.8125
# Hamming loss:
# 0.1642578125
# Hamming score:
# 0.304014283179035
# Partial accuracy:
# 0.8357421875
# Label wise accuracy:
# [0.9140625 0.71875   0.7109375 0.8125    0.953125  0.859375  0.71875
#  0.796875  0.8046875 0.828125  0.953125  0.828125  0.8828125 0.9140625
#  0.9453125 0.984375  0.953125  0.9609375 0.6953125 0.6171875 0.828125
#  0.5546875 0.96875   0.9140625 0.8515625 0.75      0.9375    0.734375
#  0.9453125 0.9140625 0.9609375 0.5625    0.859375  0.640625  0.8046875
#  0.9609375 0.7578125 0.9296875 0.9296875 0.7734375]
# Loss:
# 0.3680584728717804
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 52 ========================
# F1 score:
# 0.4529280152762399
# Recall:
# 0.3312445041937229
# Precision:
# 0.7961588541666667
# Hamming loss:
# 0.1638671875
# Hamming score:
# 0.31487071892058105
# Partial accuracy:
# 0.8361328125
# Label wise accuracy:
# [0.8671875 0.8203125 0.71875   0.7578125 0.9765625 0.890625  0.8359375
#  0.7734375 0.734375  0.8125    0.96875   0.7890625 0.828125  0.9375
#  0.953125  0.9453125 0.90625   0.9453125 0.7890625 0.6640625 0.7265625
#  0.625     0.9765625 0.890625  0.8203125 0.734375  0.984375  0.7265625
#  0.9375    0.9609375 0.921875  0.65625   0.8125    0.6953125 0.8046875
#  0.9453125 0.8125    0.828125  0.9296875 0.7421875]
# Loss:
# 0.37727656960487366
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 53 ========================
# F1 score:
# 0.4526348580580991
# Recall:
# 0.3304238513222888
# Precision:
# 0.8120070684523809
# Hamming loss:
# 0.16328125
# Hamming score:
# 0.31458585901945274
# Partial accuracy:
# 0.83671875
# Label wise accuracy:
# [0.859375  0.7734375 0.7265625 0.7890625 0.9765625 0.875     0.75
#  0.6953125 0.703125  0.859375  0.9765625 0.8046875 0.8046875 0.90625
#  0.9453125 0.890625  0.90625   0.9609375 0.875     0.71875   0.734375
#  0.640625  0.953125  0.890625  0.796875  0.7578125 0.9453125 0.6875
#  0.8515625 0.96875   0.953125  0.65625   0.78125   0.75      0.90625
#  0.9453125 0.8828125 0.8984375 0.8984375 0.7734375]
# Loss:
# 0.3854917585849762
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 54 ========================
# F1 score:
# 0.4316549991841449
# Recall:
# 0.3140627167970918
# Precision:
# 0.8019252232142857
# Hamming loss:
# 0.168359375
# Hamming score:
# 0.2962736699064824
# Partial accuracy:
# 0.831640625
# Label wise accuracy:
# [0.84375   0.6953125 0.703125  0.7109375 0.96875   0.8671875 0.859375
#  0.7578125 0.7734375 0.859375  0.9375    0.8828125 0.90625   0.9140625
#  0.921875  0.96875   0.9375    0.953125  0.796875  0.640625  0.703125
#  0.578125  0.96875   0.9140625 0.7890625 0.71875   0.9453125 0.7734375
#  0.9375    0.9140625 0.9140625 0.578125  0.78125   0.7578125 0.828125
#  0.9296875 0.828125  0.8515625 0.875     0.78125  ]
# Loss:
# 0.3782900869846344
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 55 ========================
# F1 score:
# 0.444653354945974
# Recall:
# 0.3217801512723388
# Precision:
# 0.8228670634920634
# Hamming loss:
# 0.1708984375
# Hamming score:
# 0.30712043139662626
# Partial accuracy:
# 0.8291015625
# Label wise accuracy:
# [0.78125   0.765625  0.625     0.8203125 0.9609375 0.8125    0.6796875
#  0.703125  0.7109375 0.859375  0.9453125 0.8125    0.8359375 0.9375
#  0.953125  0.9609375 0.953125  0.984375  0.765625  0.65625   0.7890625
#  0.546875  0.9453125 0.90625   0.78125   0.78125   0.9921875 0.734375
#  0.9140625 0.953125  0.9453125 0.6875    0.734375  0.75      0.8671875
#  0.9453125 0.8125    0.8984375 0.8671875 0.7890625]
# Loss:
# 0.37810516357421875
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 56 ========================
# F1 score:
# 0.44893537982377957
# Recall:
# 0.32410519168331664
# Precision:
# 0.8380673363095238
# Hamming loss:
# 0.1619140625
# Hamming score:
# 0.30554029304029307
# Partial accuracy:
# 0.8380859375
# Label wise accuracy:
# [0.8515625 0.7578125 0.640625  0.84375   0.96875   0.828125  0.8359375
#  0.7890625 0.734375  0.8515625 0.9375    0.796875  0.859375  0.9609375
#  0.9765625 0.9140625 0.9375    0.96875   0.71875   0.65625   0.8203125
#  0.5625    0.9609375 0.90625   0.8515625 0.7734375 0.96875   0.7109375
#  0.921875  0.9765625 0.9375    0.640625  0.859375  0.71875   0.8046875
#  0.9609375 0.71875   0.8359375 0.953125  0.8125   ]
# Loss:
# 0.3635590076446533
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 57 ========================
# F1 score:
# 0.4320017537532408
# Recall:
# 0.31222916623307245
# Precision:
# 0.8204334077380953
# Hamming loss:
# 0.1669921875
# Hamming score:
# 0.29182397463647464
# Partial accuracy:
# 0.8330078125
# Label wise accuracy:
# [0.8671875 0.796875  0.6328125 0.78125   0.953125  0.84375   0.734375
#  0.7421875 0.765625  0.921875  0.9453125 0.734375  0.8359375 0.953125
#  0.953125  0.9296875 0.96875   0.9453125 0.75      0.6015625 0.765625
#  0.5703125 0.9609375 0.890625  0.828125  0.71875   0.9765625 0.7890625
#  0.90625   0.9296875 0.96875   0.5859375 0.828125  0.71875   0.859375
#  0.953125  0.765625  0.921875  0.9453125 0.78125  ]
# Loss:
# 0.370433509349823
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 58 ========================
# F1 score:
# 0.47042170854815984
# Recall:
# 0.3356213881604507
# Precision:
# 0.8849330357142857
# Hamming loss:
# 0.155859375
# Hamming score:
# 0.32102413645382394
# Partial accuracy:
# 0.844140625
# Label wise accuracy:
# [0.875     0.71875   0.6328125 0.78125   0.9921875 0.8984375 0.734375
#  0.78125   0.7578125 0.859375  0.96875   0.828125  0.84375   0.9609375
#  0.96875   0.9296875 0.9609375 0.9765625 0.75      0.75      0.875
#  0.578125  0.953125  0.890625  0.859375  0.734375  0.9609375 0.734375
#  0.921875  0.921875  0.9609375 0.765625  0.7421875 0.7109375 0.84375
#  0.9453125 0.71875   0.890625  0.90625   0.8828125]
# Loss:
# 0.3555467128753662
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 59 ========================
# F1 score:
# 0.4455606144049449
# Recall:
# 0.32068207400238646
# Precision:
# 0.8113188244047619
# Hamming loss:
# 0.1587890625
# Hamming score:
# 0.30357435533216787
# Partial accuracy:
# 0.8412109375
# Label wise accuracy:
# [0.84375   0.8671875 0.6875    0.8359375 0.96875   0.875     0.7734375
#  0.8046875 0.703125  0.890625  0.875     0.7890625 0.8515625 0.9609375
#  0.96875   0.921875  0.90625   0.9609375 0.78125   0.6953125 0.84375
#  0.640625  0.953125  0.8671875 0.796875  0.7109375 0.90625   0.7421875
#  0.9453125 0.9609375 0.9453125 0.6953125 0.796875  0.75      0.859375
#  0.90625   0.7890625 0.890625  0.90625   0.78125  ]
# Loss:
# 0.3745967745780945
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 60 ========================
# F1 score:
# 0.4582103436048386
# Recall:
# 0.32947522312756683
# Precision:
# 0.8433314732142857
# Hamming loss:
# 0.159375
# Hamming score:
# 0.3131133298125486
# Partial accuracy:
# 0.840625
# Label wise accuracy:
# [0.890625  0.7265625 0.6640625 0.8046875 0.984375  0.828125  0.765625
#  0.796875  0.8125    0.859375  0.9609375 0.7734375 0.875     0.9765625
#  0.984375  0.953125  0.96875   0.9609375 0.703125  0.6796875 0.8203125
#  0.5703125 1.        0.8828125 0.8671875 0.6875    0.9296875 0.71875
#  0.921875  0.9765625 0.9765625 0.71875   0.84375   0.671875  0.8125
#  0.9375    0.7421875 0.875     0.9296875 0.7734375]
# Loss:
# 0.35710474848747253
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 61 ========================
# F1 score:
# 0.4545320947423245
# Recall:
# 0.3291004498208082
# Precision:
# 0.8210193452380952
# Hamming loss:
# 0.169140625
# Hamming score:
# 0.31155828061848284
# Partial accuracy:
# 0.830859375
# Label wise accuracy:
# [0.90625   0.75      0.6796875 0.84375   0.9765625 0.8515625 0.7265625
#  0.765625  0.8046875 0.765625  0.9453125 0.8828125 0.8671875 0.953125
#  0.953125  0.9609375 0.9140625 0.9609375 0.6953125 0.578125  0.90625
#  0.5546875 0.921875  0.9140625 0.8125    0.7265625 0.953125  0.703125
#  0.90625   0.9140625 0.9453125 0.640625  0.75      0.765625  0.7890625
#  0.921875  0.7421875 0.875     0.921875  0.7890625]
# Loss:
# 0.3677350878715515
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 62 ========================
# F1 score:
# 0.44738185613387527
# Recall:
# 0.3132848163121601
# Precision:
# 0.882586185515873
# Hamming loss:
# 0.1751953125
# Hamming score:
# 0.30362646251318126
# Partial accuracy:
# 0.8248046875
# Label wise accuracy:
# [0.9375    0.7421875 0.7109375 0.796875  0.9765625 0.8671875 0.75
#  0.7734375 0.703125  0.875     0.953125  0.8046875 0.8203125 0.9453125
#  0.9609375 0.9375    0.953125  0.96875   0.7109375 0.4921875 0.90625
#  0.5       0.9609375 0.859375  0.890625  0.6953125 0.953125  0.6875
#  0.9140625 0.921875  0.96875   0.5859375 0.765625  0.703125  0.71875
#  0.953125  0.7265625 0.8671875 0.890625  0.84375  ]
# Loss:
# 0.3718181550502777
#
# ====================================================================
#
#
# ======================== Epoch: 1, Batch: 63 ========================
# F1 score:
# 0.4402834686007577
# Recall:
# 0.3140234242371191
# Precision:
# 0.8408110119047618
# Hamming loss:
# 0.175390625
# Hamming score:
# 0.3001372453118777
# Partial accuracy:
# 0.824609375
# Label wise accuracy:
# [0.90625   0.71875   0.640625  0.8046875 0.953125  0.8515625 0.7890625
#  0.734375  0.7578125 0.8671875 0.953125  0.765625  0.828125  0.9140625
#  0.96875   0.90625   0.9375    0.9453125 0.6328125 0.5859375 0.859375
#  0.6328125 0.953125  0.890625  0.8515625 0.71875   0.921875  0.7109375
# ...
#  0.75      0.859375  0.96875   0.953125  0.8046875 0.8828125 0.9140625
#  0.9296875 0.9765625 0.921875  0.9609375 0.8046875 0.703125  0.8984375
#  0.75      0.9296875 0.890625  0.8984375 0.6953125 0.96875   0.734375
#  0.9375    0.9453125 0.9140625 0.75      0.734375  0.828125  0.828125
#  0.9765625 0.8984375 0.90625   0.953125  0.890625 ]
# Loss:
# 0.2830609381198883
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 299 ========================
# F1 score:
# 0.6429939118023766
# Recall:
# 0.527376681478244
# Precision:
# 0.8992618709415585
# Hamming loss:
# 0.1234375
# Hamming score:
# 0.5023097020167333
# Partial accuracy:
# 0.8765625
# Label wise accuracy:
# [0.8515625 0.7890625 0.8203125 0.8046875 0.984375  0.9453125 0.796875
#  0.78125   0.8125    0.9453125 0.9921875 0.796875  0.859375  0.9296875
#  0.96875   0.984375  0.953125  0.96875   0.84375   0.75      0.9609375
#  0.7734375 0.953125  0.8828125 0.890625  0.7265625 0.9765625 0.734375
#  0.953125  0.90625   0.953125  0.828125  0.7578125 0.828125  0.8203125
#  0.96875   0.9375    0.875     0.953125  0.8046875]
# Loss:
# 0.2646942734718323
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 300 ========================
# F1 score:
# 0.620169059821972
# Recall:
# 0.5114841321872572
# Precision:
# 0.8637523934398934
# Hamming loss:
# 0.12421875
# Hamming score:
# 0.47073649007242757
# Partial accuracy:
# 0.87578125
# Label wise accuracy:
# [0.8984375 0.8046875 0.7421875 0.78125   0.984375  0.953125  0.8046875
#  0.7734375 0.8984375 0.9375    0.9765625 0.734375  0.890625  0.9453125
#  0.9453125 0.984375  0.9453125 0.9453125 0.8828125 0.7421875 0.9296875
#  0.7421875 0.96875   0.9296875 0.890625  0.7578125 0.9375    0.7578125
#  0.90625   0.9609375 0.9609375 0.7578125 0.84375   0.7578125 0.828125
#  1.        0.859375  0.890625  0.90625   0.875    ]
# Loss:
# 0.27476009726524353
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 301 ========================
# F1 score:
# 0.6317950186846046
# Recall:
# 0.5228285603285604
# Precision:
# 0.8733707048160173
# Hamming loss:
# 0.119921875
# Hamming score:
# 0.4844480931394994
# Partial accuracy:
# 0.880078125
# Label wise accuracy:
# [0.84375   0.8203125 0.78125   0.75      0.9765625 0.8984375 0.7890625
#  0.78125   0.8828125 0.921875  0.96875   0.84375   0.796875  0.953125
#  0.96875   0.984375  0.90625   0.9609375 0.78125   0.796875  0.9609375
#  0.8046875 0.953125  0.9296875 0.90625   0.8515625 0.9453125 0.734375
#  0.921875  0.96875   0.9375    0.8046875 0.84375   0.828125  0.8515625
#  0.984375  0.890625  0.84375   0.9296875 0.90625  ]
# Loss:
# 0.2709729075431824
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 302 ========================
# F1 score:
# 0.6463914169863616
# Recall:
# 0.5334336504488159
# Precision:
# 0.9035376082251083
# Hamming loss:
# 0.1255859375
# Hamming score:
# 0.5015459526431494
# Partial accuracy:
# 0.8744140625
# Label wise accuracy:
# [0.8984375 0.734375  0.65625   0.859375  0.9765625 0.90625   0.796875
#  0.8046875 0.8671875 0.9296875 0.9765625 0.828125  0.890625  0.96875
#  0.9375    1.        0.9609375 0.9609375 0.8359375 0.71875   0.9140625
#  0.7265625 0.984375  0.8828125 0.9375    0.7890625 0.9765625 0.65625
#  0.9296875 0.9140625 0.9609375 0.8125    0.8515625 0.796875  0.7734375
#  0.9765625 0.890625  0.8671875 0.9375    0.890625 ]
# Loss:
# 0.27038460969924927
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 303 ========================
# F1 score:
# 0.6204456962460858
# Recall:
# 0.5176644861215174
# Precision:
# 0.8591814869158618
# Hamming loss:
# 0.126171875
# Hamming score:
# 0.47554005112024417
# Partial accuracy:
# 0.873828125
# Label wise accuracy:
# [0.90625   0.7265625 0.71875   0.84375   0.9921875 0.8828125 0.828125
#  0.7890625 0.875     0.90625   0.9609375 0.796875  0.890625  0.9375
#  0.9765625 0.9921875 0.9453125 0.9765625 0.796875  0.734375  0.8984375
#  0.78125   0.9765625 0.921875  0.953125  0.703125  0.953125  0.7265625
#  0.9609375 0.96875   0.9375    0.8203125 0.7578125 0.78125   0.828125
#  0.96875   0.875     0.875     0.953125  0.8359375]
# Loss:
# 0.27169734239578247
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 304 ========================
# F1 score:
# 0.6392076951733945
# Recall:
# 0.5310378206862582
# Precision:
# 0.8797153150668775
# Hamming loss:
# 0.114453125
# Hamming score:
# 0.49299297707500833
# Partial accuracy:
# 0.885546875
# Label wise accuracy:
# [0.890625  0.8046875 0.796875  0.796875  0.96875   0.9296875 0.8359375
#  0.8359375 0.890625  0.984375  0.9375    0.796875  0.8828125 0.9375
#  0.9453125 0.9921875 0.9375    0.9453125 0.828125  0.75      0.921875
#  0.8046875 0.9375    0.9296875 0.8828125 0.6796875 0.953125  0.8203125
#  0.9453125 0.9453125 0.9609375 0.78125   0.8125    0.8515625 0.8984375
#  0.9921875 0.875     0.921875  0.9296875 0.890625 ]
# Loss:
# 0.26603963971138
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 305 ========================
# F1 score:
# 0.6312230854883031
# Recall:
# 0.5263099747474748
# Precision:
# 0.8782320544039295
# Hamming loss:
# 0.12265625
# Hamming score:
# 0.4817559993111464
# Partial accuracy:
# 0.87734375
# Label wise accuracy:
# [0.8984375 0.8203125 0.8203125 0.890625  0.9765625 0.8828125 0.796875
#  0.78125   0.8671875 0.90625   0.9453125 0.84375   0.84375   0.9609375
#  0.9375    0.9765625 0.9296875 0.984375  0.8203125 0.765625  0.9296875
#  0.7734375 0.984375  0.875     0.890625  0.65625   0.9609375 0.703125
#  0.953125  0.953125  0.953125  0.796875  0.8203125 0.8125    0.78125
#  0.984375  0.9375    0.875     0.9375    0.8671875]
# Loss:
# 0.2737337648868561
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 306 ========================
# F1 score:
# 0.5992748002658383
# Recall:
# 0.4915801965089649
# Precision:
# 0.8422464037698413
# Hamming loss:
# 0.1326171875
# Hamming score:
# 0.45569831580286546
# Partial accuracy:
# 0.8673828125
# Label wise accuracy:
# [0.9140625 0.765625  0.78125   0.7734375 0.9921875 0.890625  0.7734375
#  0.7890625 0.828125  0.9140625 0.9609375 0.71875   0.90625   0.9453125
#  0.984375  0.96875   0.9140625 0.96875   0.8203125 0.796875  0.90625
#  0.7890625 0.96875   0.8671875 0.890625  0.703125  0.9765625 0.7109375
#  0.9609375 0.90625   0.8984375 0.75      0.796875  0.78125   0.859375
#  0.9609375 0.84375   0.90625   0.9609375 0.8515625]
# Loss:
# 0.28838205337524414
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 307 ========================
# F1 score:
# 0.6065717912083821
# Recall:
# 0.5070855793512044
# Precision:
# 0.8166415832431457
# Hamming loss:
# 0.129296875
# Hamming score:
# 0.4609147796647797
# Partial accuracy:
# 0.870703125
# Label wise accuracy:
# [0.90625   0.78125   0.8203125 0.78125   0.984375  0.921875  0.7734375
#  0.7578125 0.8359375 0.9375    0.96875   0.8046875 0.8984375 0.9375
#  0.9609375 0.9609375 0.9140625 0.953125  0.8671875 0.7421875 0.875
#  0.6953125 0.9765625 0.9296875 0.890625  0.7109375 0.984375  0.7578125
#  0.8984375 0.9296875 0.9609375 0.7421875 0.796875  0.8359375 0.828125
#  0.96875   0.8828125 0.8671875 0.953125  0.8359375]
# Loss:
# 0.28346535563468933
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 308 ========================
# F1 score:
# 0.6226169188968953
# Recall:
# 0.5192274739149739
# Precision:
# 0.8468034136002885
# Hamming loss:
# 0.1236328125
# Hamming score:
# 0.47861076194026564
# Partial accuracy:
# 0.8763671875
# Label wise accuracy:
# [0.8984375 0.8046875 0.7578125 0.8046875 1.        0.9296875 0.8125
#  0.84375   0.875     0.9375    0.9609375 0.8203125 0.859375  0.9296875
#  0.96875   1.        0.9453125 0.984375  0.8828125 0.75      0.9296875
#  0.71875   0.984375  0.921875  0.8984375 0.6953125 0.953125  0.7421875
#  0.9453125 0.9375    0.953125  0.78125   0.7578125 0.796875  0.796875
#  0.953125  0.8984375 0.8515625 0.9296875 0.84375  ]
# Loss:
# 0.26859307289123535
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 309 ========================
# F1 score:
# 0.6392535233733788
# Recall:
# 0.5311156183226495
# Precision:
# 0.878278318903319
# Hamming loss:
# 0.1203125
# Hamming score:
# 0.49239437862484736
# Partial accuracy:
# 0.8796875
# Label wise accuracy:
# [0.8515625 0.828125  0.75      0.8203125 0.9921875 0.9609375 0.8203125
#  0.7734375 0.8515625 0.9375    0.9609375 0.828125  0.8984375 0.953125
#  0.9609375 0.984375  0.9296875 0.9765625 0.921875  0.7578125 0.9375
#  0.78125   0.9453125 0.9453125 0.90625   0.703125  0.9453125 0.71875
#  0.90625   0.96875   0.9453125 0.7734375 0.8203125 0.75      0.875
#  0.9765625 0.9453125 0.8671875 0.90625   0.8125   ]
# Loss:
# 0.26593470573425293
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 310 ========================
# F1 score:
# 0.6159789104139632
# Recall:
# 0.5091066485597735
# Precision:
# 0.8865006087662337
# Hamming loss:
# 0.1185546875
# Hamming score:
# 0.4732399761696637
# Partial accuracy:
# 0.8814453125
# Label wise accuracy:
# [0.890625  0.703125  0.734375  0.8515625 1.        0.9375    0.8515625
#  0.765625  0.8984375 0.921875  0.9375    0.8046875 0.84375   0.9765625
#  0.984375  0.9765625 0.921875  0.9453125 0.890625  0.78125   0.921875
#  0.7734375 0.96875   0.8984375 0.921875  0.7578125 0.96875   0.796875
#  0.953125  0.9765625 0.921875  0.828125  0.8203125 0.7578125 0.8203125
#  0.9921875 0.8515625 0.9375    0.953125  0.8203125]
# Loss:
# 0.2666741907596588
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 311 ========================
# F1 score:
# 0.5903964044100829
# Recall:
# 0.48626447337384837
# Precision:
# 0.8311755952380953
# Hamming loss:
# 0.12734375
# Hamming score:
# 0.44396764260045507
# Partial accuracy:
# 0.87265625
# Label wise accuracy:
# [0.8828125 0.7890625 0.7109375 0.8203125 0.984375  0.9375    0.8203125
#  0.7734375 0.84375   0.9375    0.9296875 0.84375   0.8828125 0.9609375
#  0.9375    0.9921875 0.953125  0.9921875 0.828125  0.7109375 0.90625
#  0.7734375 0.921875  0.90625   0.8046875 0.78125   0.96875   0.6796875
#  0.9296875 0.9453125 0.9765625 0.796875  0.78125   0.8671875 0.8125
#  1.        0.8671875 0.890625  0.96875   0.796875 ]
# Loss:
# 0.282396525144577
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 312 ========================
# F1 score:
# 0.6084354551957443
# Recall:
# 0.5028301993145744
# Precision:
# 0.8690805938852814
# Hamming loss:
# 0.1255859375
# Hamming score:
# 0.46187036704614826
# Partial accuracy:
# 0.8744140625
# Label wise accuracy:
# [0.9140625 0.7578125 0.8125    0.8359375 0.9765625 0.890625  0.8046875
#  0.765625  0.875     0.9375    0.9765625 0.765625  0.8671875 0.8984375
#  0.90625   0.9765625 0.9296875 0.953125  0.875     0.796875  0.9453125
#  0.7890625 0.9375    0.9375    0.859375  0.7578125 0.9296875 0.7109375
#  0.890625  0.953125  0.9375    0.7890625 0.7890625 0.828125  0.8671875
#  0.9765625 0.8828125 0.8984375 0.9140625 0.8671875]
# Loss:
# 0.2771753966808319
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 313 ========================
# F1 score:
# 0.5929856808501572
# Recall:
# 0.4846518390463703
# Precision:
# 0.8621416560869686
# Hamming loss:
# 0.1375
# Hamming score:
# 0.4458644437160062
# Partial accuracy:
# 0.8625
# Label wise accuracy:
# [0.875     0.7890625 0.7265625 0.7578125 0.984375  0.8828125 0.7421875
#  0.8046875 0.859375  0.9140625 0.9296875 0.796875  0.8359375 0.9375
#  0.96875   0.9765625 0.9375    0.9765625 0.8515625 0.7109375 0.828125
#  0.7578125 0.953125  0.90625   0.8828125 0.7578125 0.953125  0.71875
#  0.9375    0.921875  0.953125  0.7421875 0.7890625 0.859375  0.7890625
#  0.9765625 0.8671875 0.8671875 0.953125  0.828125 ]
# Loss:
# 0.28869006037712097
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 314 ========================
# F1 score:
# 0.6177943827167415
# Recall:
# 0.5180961616508492
# Precision:
# 0.8510157377344878
# Hamming loss:
# 0.1263671875
# Hamming score:
# 0.4704667039455642
# Partial accuracy:
# 0.8736328125
# Label wise accuracy:
# [0.9453125 0.765625  0.703125  0.78125   1.        0.921875  0.8515625
#  0.828125  0.859375  0.9296875 0.96875   0.75      0.890625  0.921875
#  0.96875   0.96875   0.9453125 0.96875   0.8671875 0.7421875 0.9296875
#  0.7265625 0.953125  0.9296875 0.9375    0.7265625 0.953125  0.7890625
#  0.9140625 0.8984375 0.953125  0.8125    0.828125  0.7890625 0.75
#  0.96875   0.8671875 0.90625   0.96875   0.765625 ]
# Loss:
# 0.27285099029541016
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 315 ========================
# F1 score:
# 0.6257488112957967
# Recall:
# 0.5086839484300422
# Precision:
# 0.8984411855505605
# Hamming loss:
# 0.1248046875
# Hamming score:
# 0.4761248542613432
# Partial accuracy:
# 0.8751953125
# Label wise accuracy:
# [0.90625   0.7578125 0.7578125 0.8359375 1.        0.9296875 0.8203125
#  0.828125  0.8671875 0.9296875 0.9375    0.71875   0.8203125 0.9453125
#  0.953125  0.9921875 0.9296875 0.9609375 0.796875  0.7890625 0.9375
#  0.7734375 0.9375    0.8984375 0.8984375 0.6953125 0.984375  0.71875
#  0.8984375 0.9296875 0.9609375 0.8671875 0.828125  0.796875  0.8203125
#  0.9921875 0.9296875 0.859375  0.9609375 0.84375  ]
# Loss:
# 0.2675444185733795
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 316 ========================
# F1 score:
# 0.6283927088231798
# Recall:
# 0.5261182419500434
# Precision:
# 0.8779394867285493
# Hamming loss:
# 0.122265625
# Hamming score:
# 0.4797822862390877
# Partial accuracy:
# 0.877734375
# Label wise accuracy:
# [0.9140625 0.7734375 0.75      0.7421875 0.9609375 0.921875  0.8359375
#  0.796875  0.8984375 0.9453125 0.9453125 0.8515625 0.875     0.90625
#  0.921875  0.9921875 0.9609375 0.9609375 0.8359375 0.734375  0.9375
#  0.75      0.9765625 0.9140625 0.8515625 0.734375  0.9453125 0.7578125
#  0.9140625 0.9296875 0.9375    0.8203125 0.859375  0.8828125 0.859375
#  0.9921875 0.84375   0.890625  0.9296875 0.859375 ]
# Loss:
# 0.2681666314601898
#
# ====================================================================
#
#
# ======================== Epoch: 2, Batch: 317 ========================
# F1 score:
# 0.6034096760229146
# Recall:
# 0.4979660385910386
# Precision:
# 0.84734297338464
# Hamming loss:
# 0.13055555555555556
# Hamming score:
# 0.4543670835337502
# Partial accuracy:
# 0.8694444444444445
# Label wise accuracy:
# [0.83333333 0.79166667 0.625      0.77777778 1.         0.95833333
#  0.86111111 0.77777778 0.80555556 0.98611111 0.98611111 0.80555556
#  0.75       0.95833333 0.97222222 0.97222222 0.94444444 0.98611111
#  0.84722222 0.73611111 0.90277778 0.75       0.94444444 0.90277778
#  0.88888889 0.73611111 0.95833333 0.75       0.91666667 0.97222222
#  0.93055556 0.75       0.75       0.86111111 0.88888889 0.98611111
#  0.77777778 0.91666667 0.94444444 0.875     ]
# Loss:
# 0.29227158427238464
#
# ====================================================================
#
# Saving model...
# Saving class-wise accuracy...
# Saving validation scores...
#
# ======================== Epoch: Avg, Batch: Avg ========================
# F1 score:
# 0.6161395507769669
# Recall:
# 0.5097360078996219
# Precision:
# 0.860328464019891
# Hamming loss:
# 0.1268733022257273
# Hamming score:
# 0.4702788799880011
# Partial accuracy:
# 0.8731266977742734
# Label wise accuracy:
# [0.89692593 0.77043901 0.75810824 0.80265565 0.98299487 0.91080113
#  0.80321427 0.79442418 0.85947632 0.93218213 0.95983395 0.80121528
#  0.86607847 0.94251939 0.95451608 0.97511939 0.9347863  0.96845974
#  0.84923217 0.76311668 0.91412548 0.75485509 0.95465026 0.90463711
#  0.89118636 0.73102874 0.95848942 0.72737579 0.92604824 0.93911289
#  0.9455124  0.78659799 0.80426853 0.81689231 0.83285138 0.9787121
#  0.87624595 0.87927182 0.94166229 0.8354446 ]
# Loss:
# 0.2766938072743852
#
# ====================================================================
